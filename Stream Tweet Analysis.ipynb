# %% [markdown]
# # Tweet Analysis

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
import psycopg2
import yaml
import psycopg2
from sqlalchemy import create_engine
import nltk
import arrow
from time import strptime
from datetime import datetime

# %% [markdown]
# ## Functions

# %%
# Function to get date from "created_at field"
def genDate(date_field):
    # Tokenize by splitting on whitespace
    temp_split = date_field.split(' ')
    # First item is month, second is day, last is year. Group together into a date
    # Paste together into a string
    temp_date = temp_split[-1] + '-' + temp_split[1] + '-' + temp_split[2]
    # Convert to datetime
    temp_date = datetime.strptime(temp_date, '%Y-%b-%d')
    # Return date string
    return(temp_date)

# %% [markdown]
# ## Connect to Database

# %% [markdown]
# ### Read in YAML File

# %%
# Read in AWS creds
with open(r'/Users/samivanecky/Git/tweeter/aws.yaml') as file:
    aws = yaml.full_load(file)

# %% [markdown]
# ### Connect to RDS

# %%
# Setup connection to tweeter DB
# Create engine string
connect_str = 'postgresql+psycopg2://' + aws['user'] + ':' + aws['password'] + '@' + aws['host'] + ':' + str(aws['port']) + '/'

# Create engine connection
engine = create_engine(connect_str)

c = engine.connect()
conn = c.connection

# %% [markdown]
# ## Load Data

# %%
tweets = pd.read_sql('SELECT * FROM stream_tweets', engine)

# %% [markdown]
# ## Clean Up Data

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93807 entries, 0 to 93806
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            93807 non-null  int64
#  1   _id              0 non-null      object
#  2   id               93807 non-null  int64
#  3   created_at       93807 non-null  object
#  4   text             93807 non-null  object
#  5   source           93807 non-null  object
#  6   truncated        0 non-null      object
#  7   geo              0 non-null      object
#  8   place            0 non-null      object
#  9   quote_count      93807 non-null  int64
#  10  reply_count      93807 non-null  int64
#  11  retweet_count    93807 non-null  int64
#  12  favorite_count   93807 non-null  int64
#  13  lang             0 non-null      object
#  14  is_quote_status  93807 non-null  bool
#  15  contributors     0 non-null      object
#  16  search_word      93807 non-null  object
# dtypes: bool(1), int64(6), object(10)
# memory usage: 11.5+ MB

# %%
tweets.head()
# Out:
#    index   _id                   id                      created_at  \
# 0      0  None  1396950007434125319  Mon May 24 22:03:30 +0000 2021
# 1      1  None  1396950007593439242  Mon May 24 22:03:30 +0000 2021
# 2      2  None  1396950009808101379  Mon May 24 22:03:31 +0000 2021
# 3      3  None  1396950017747963908  Mon May 24 22:03:32 +0000 2021
# 4      4  None  1396950020264370178  Mon May 24 22:03:33 +0000 2021
#
#                                                 text  \
# 0  RT @TheSteinLine: Memphis' OT play-in victory ...
# 1  RT @nchan: Spurs players setting up an in-flig...
# 2  RT @TheSteinLine: Memphis' OT play-in victory ...
# 3  RT @XXL: Gucci Mane the only rapper to double ...
# 4  RT @GBEshoddy: miles bridges said “feel like c...
#
#                                               source truncated   geo place  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...      None  None  None
# 1  <a href="http://twitter.com/download/iphone" r...      None  None  None
# 2  <a href="http://twitter.com/download/iphone" r...      None  None  None
# 3  <a href="http://twitter.com/download/iphone" r...      None  None  None
# 4  <a href="http://twitter.com/download/iphone" r...      None  None  None
#
#    quote_count  reply_count  retweet_count  favorite_count  lang  \
# 0            0            0              0               0  None
# 1            0            0              0               0  None
# 2            0            0              0               0  None
# 3            0            0              0               0  None
# 4            0            0              0               0  None
#
#    is_quote_status contributors search_word
# 0            False         None         NBA
# 1            False         None         NBA
# 2            False         None         NBA
# 3            False         None         NBA
# 4             True         None         NBA

# %%
# Create dates column using datefinder on "created_at"
tweets['date'] = tweets['created_at'].apply(genDate)

# %%
tweets
# Out:
#        index   _id                   id                      created_at  \
# 0          0  None  1396950007434125319  Mon May 24 22:03:30 +0000 2021
# 1          1  None  1396950007593439242  Mon May 24 22:03:30 +0000 2021
# 2          2  None  1396950009808101379  Mon May 24 22:03:31 +0000 2021
# 3          3  None  1396950017747963908  Mon May 24 22:03:32 +0000 2021
# 4          4  None  1396950020264370178  Mon May 24 22:03:33 +0000 2021
# ...      ...   ...                  ...                             ...
# 93802  93802  None  1398647403453026305  Sat May 29 14:28:21 +0000 2021
# 93803  93803  None  1398647408695840769  Sat May 29 14:28:22 +0000 2021
# 93804  93804  None  1398647412760231941  Sat May 29 14:28:23 +0000 2021
# 93805  93805  None  1398647415817883650  Sat May 29 14:28:24 +0000 2021
# 93806  93806  None  1398647423866753025  Sat May 29 14:28:26 +0000 2021
#
#                                                     text  \
# 0      RT @TheSteinLine: Memphis' OT play-in victory ...
# 1      RT @nchan: Spurs players setting up an in-flig...
# 2      RT @TheSteinLine: Memphis' OT play-in victory ...
# 3      RT @XXL: Gucci Mane the only rapper to double ...
# 4      RT @GBEshoddy: miles bridges said “feel like c...
# ...                                                  ...
# 93802  Y'all brought the energy to @StateFarmArena la...
# 93803  RT @SportsCenter: Jayson Tatum is now the only...
# 93804  Clippers now the favorite (-115) to win their ...
# 93805  RT @DrewD977ESPN: The best tweet of the night....
# 93806  All of those Celtics titles in the 50s and 60s...
#
#                                                   source truncated   geo  \
# 0      <a href="https://mobile.twitter.com" rel="nofo...      None  None
# 1      <a href="http://twitter.com/download/iphone" r...      None  None
# 2      <a href="http://twitter.com/download/iphone" r...      None  None
# 3      <a href="http://twitter.com/download/iphone" r...      None  None
# 4      <a href="http://twitter.com/download/iphone" r...      None  None
# ...                                                  ...       ...   ...
# 93802  <a href="https://mobile.twitter.com" rel="nofo...      None  None
# 93803  <a href="http://twitter.com/download/iphone" r...      None  None
# 93804  <a href="http://twitter.com/download/iphone" r...      None  None
# 93805  <a href="http://twitter.com/download/iphone" r...      None  None
# 93806  <a href="http://twitter.com/#!/download/ipad" ...      None  None
#
#       place  quote_count  reply_count  retweet_count  favorite_count  lang  \
# 0      None            0            0              0               0  None
# 1      None            0            0              0               0  None
# 2      None            0            0              0               0  None
# 3      None            0            0              0               0  None
# 4      None            0            0              0               0  None
# ...     ...          ...          ...            ...             ...   ...
# 93802  None            0            0              0               0  None
# 93803  None            0            0              0               0  None
# 93804  None            0            0              0               0  None
# 93805  None            0            0              0               0  None
# 93806  None            0            0              0               0  None
#
#        is_quote_status contributors search_word       date
# 0                False         None         NBA 2021-05-24
# 1                False         None         NBA 2021-05-24
# 2                False         None         NBA 2021-05-24
# 3                False         None         NBA 2021-05-24
# 4                 True         None         NBA 2021-05-24
# ...                ...          ...         ...        ...
# 93802            False         None         NBA 2021-05-29
# 93803            False         None         NBA 2021-05-29
# 93804            False         None         NBA 2021-05-29
# 93805             True         None         NBA 2021-05-29
# 93806            False         None         NBA 2021-05-29
#
# [93807 rows x 18 columns]
